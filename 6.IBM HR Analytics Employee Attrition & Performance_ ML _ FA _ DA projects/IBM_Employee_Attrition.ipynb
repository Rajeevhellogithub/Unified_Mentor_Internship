# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import warnings
# warnings.filterwarnings('ignore')
# pd.set_option('display.max_columns', 35)

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('WA_Fn_UseC_HR_Employee_Attrition.csv')
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# df.head(3).T

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Columns: 35 entries, Age to YearsWithCurrManager
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
print( df.select_dtypes(exclude='int64').columns.tolist() )
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %%
print( df.select_dtypes(exclude='object').columns.tolist() )
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
df.select_dtypes(exclude='int64').head(3).T
# df.select_dtypes(include='object').head(3).T
# Out:
#                               0                       1  \
# Attrition                   Yes                      No
# BusinessTravel    Travel_Rarely       Travel_Frequently
# Department                Sales  Research & Development
# EducationField    Life Sciences           Life Sciences
# Gender                   Female                    Male
# JobRole         Sales Executive      Research Scientist
# MaritalStatus            Single                 Married
# Over18                        Y                       Y
# OverTime                    Yes                      No
#
#                                      2
# Attrition                          Yes
# BusinessTravel           Travel_Rarely
# Department      Research & Development
# EducationField                   Other
# Gender                            Male
# JobRole          Laboratory Technician
# MaritalStatus                   Single
# Over18                               Y
# OverTime                           Yes

# %%
df.select_dtypes(exclude='object').head(3).T
# df.select_dtypes(include='int64').head(3).T
# Out:
#                               0      1     2
# Age                          41     49    37
# DailyRate                  1102    279  1373
# DistanceFromHome              1      8     2
# Education                     2      1     2
# EmployeeCount                 1      1     1
# EmployeeNumber                1      2     4
# EnvironmentSatisfaction       2      3     4
# HourlyRate                   94     61    92
# JobInvolvement                3      2     2
# JobLevel                      2      2     1
# JobSatisfaction               4      2     3
# MonthlyIncome              5993   5130  2090
# MonthlyRate               19479  24907  2396
# NumCompaniesWorked            8      1     6
# PercentSalaryHike            11     23    15
# PerformanceRating             3      4     3
# RelationshipSatisfaction      1      4     2
# StandardHours                80     80    80
# StockOptionLevel              0      1     0
# TotalWorkingYears             8     10     7
# ...

# %% [markdown]
# ## Check Null Values

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Age                         0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# EducationField              0.0
# EmployeeCount               0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# Gender                      0.0
# HourlyRate                  0.0
# JobInvolvement              0.0
# JobLevel                    0.0
# JobRole                     0.0
# JobSatisfaction             0.0
# MaritalStatus               0.0
# MonthlyIncome               0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# Over18                      0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# RelationshipSatisfaction    0.0
# StandardHours               0.0
# StockOptionLevel            0.0
# TotalWorkingYears           0.0
# ...

# %% [markdown]
# There are no null values in any columns

# %% [markdown]
# ## Unique Values and Counts I

# %%
# for col in df.columns:
#     print(f"Total unique values in column '{col}': {df[col].nunique()}")

# %%
# len(df['Attrition'].unique())

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# column_names = df.columns.tolist()
# unique_counts = {}
# for col in column_names:
#     unique_counts[col] = df[col].nunique()
# unique_counts_df = pd.DataFrame(list(unique_counts.items()), columns=['Col_Name', 'Unique_Values_Counts'])
# unique_counts_df

# %%
print( column_names )
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
print( unique_counts )
# Out:
# {'Age': 43, 'Attrition': 2, 'BusinessTravel': 3, 'DailyRate': 886, 'Department': 3, 'DistanceFromHome': 29, 'Education': 5, 'EducationField': 6, 'EmployeeCount': 1, 'EmployeeNumber': 1470, 'EnvironmentSatisfaction': 4, 'Gender': 2, 'HourlyRate': 71, 'JobInvolvement': 4, 'JobLevel': 5, 'JobRole': 9, 'JobSatisfaction': 4, 'MaritalStatus': 3, 'MonthlyIncome': 1349, 'MonthlyRate': 1427, 'NumCompaniesWorked': 10, 'Over18': 1, 'OverTime': 2, 'PercentSalaryHike': 15, 'PerformanceRating': 2, 'RelationshipSatisfaction': 4, 'StandardHours': 1, 'StockOptionLevel': 4, 'TotalWorkingYears': 40, 'TrainingTimesLastYear': 7, 'WorkLifeBalance': 4, 'YearsAtCompany': 37, 'YearsInCurrentRole': 19, 'YearsSinceLastPromotion': 16, 'YearsWithCurrManager': 18}

# %%
print( unique_counts.items() )
# Out:
# dict_items([('Age', 43), ('Attrition', 2), ('BusinessTravel', 3), ('DailyRate', 886), ('Department', 3), ('DistanceFromHome', 29), ('Education', 5), ('EducationField', 6), ('EmployeeCount', 1), ('EmployeeNumber', 1470), ('EnvironmentSatisfaction', 4), ('Gender', 2), ('HourlyRate', 71), ('JobInvolvement', 4), ('JobLevel', 5), ('JobRole', 9), ('JobSatisfaction', 4), ('MaritalStatus', 3), ('MonthlyIncome', 1349), ('MonthlyRate', 1427), ('NumCompaniesWorked', 10), ('Over18', 1), ('OverTime', 2), ('PercentSalaryHike', 15), ('PerformanceRating', 2), ('RelationshipSatisfaction', 4), ('StandardHours', 1), ('StockOptionLevel', 4), ('TotalWorkingYears', 40), ('TrainingTimesLastYear', 7), ('WorkLifeBalance', 4), ('YearsAtCompany', 37), ('YearsInCurrentRole', 19), ('YearsSinceLastPromotion', 16), ('YearsWithCurrManager', 18)])

# %%
print( list(unique_counts.items()) )
# Out:
# [('Age', 43), ('Attrition', 2), ('BusinessTravel', 3), ('DailyRate', 886), ('Department', 3), ('DistanceFromHome', 29), ('Education', 5), ('EducationField', 6), ('EmployeeCount', 1), ('EmployeeNumber', 1470), ('EnvironmentSatisfaction', 4), ('Gender', 2), ('HourlyRate', 71), ('JobInvolvement', 4), ('JobLevel', 5), ('JobRole', 9), ('JobSatisfaction', 4), ('MaritalStatus', 3), ('MonthlyIncome', 1349), ('MonthlyRate', 1427), ('NumCompaniesWorked', 10), ('Over18', 1), ('OverTime', 2), ('PercentSalaryHike', 15), ('PerformanceRating', 2), ('RelationshipSatisfaction', 4), ('StandardHours', 1), ('StockOptionLevel', 4), ('TotalWorkingYears', 40), ('TrainingTimesLastYear', 7), ('WorkLifeBalance', 4), ('YearsAtCompany', 37), ('YearsInCurrentRole', 19), ('YearsSinceLastPromotion', 16), ('YearsWithCurrManager', 18)]

# %%
unique_counts_df
# Out:
#                     Col_Name  Unique_Values_Counts
# 0                        Age                    43
# 1                  Attrition                     2
# 2             BusinessTravel                     3
# 3                  DailyRate                   886
# 4                 Department                     3
# 5           DistanceFromHome                    29
# 6                  Education                     5
# 7             EducationField                     6
# 8              EmployeeCount                     1
# 9             EmployeeNumber                  1470
# 10   EnvironmentSatisfaction                     4
# 11                    Gender                     2
# 12                HourlyRate                    71
# 13            JobInvolvement                     4
# 14                  JobLevel                     5
# 15                   JobRole                     9
# 16           JobSatisfaction                     4
# ...

# %%
print( unique_counts_df[unique_counts_df['Unique_Values_Counts'] <= 20]['Col_Name'].tolist() )
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'Education', 'EducationField', 'EmployeeCount', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
print( unique_counts_df[unique_counts_df['Unique_Values_Counts'] > 20]['Col_Name'].tolist() )
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'EmployeeNumber', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'TotalWorkingYears', 'YearsAtCompany']

# %%
low_cardinality_cols = unique_counts_df[unique_counts_df['Unique_Values_Counts'] <= 20]['Col_Name'].tolist()

# %%
for col in low_cardinality_cols:
    print(f"unique values in column '{col}':\n {df[col].unique().tolist()}\n")
# Out:
# unique values in column 'Attrition':
#  ['Yes', 'No']
#
# unique values in column 'BusinessTravel':
#  ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
#
# unique values in column 'Department':
#  ['Sales', 'Research & Development', 'Human Resources']
#
# unique values in column 'Education':
#  [2, 1, 4, 3, 5]
#
# unique values in column 'EducationField':
#  ['Life Sciences', 'Other', 'Medical', 'Marketing', 'Technical Degree', 'Human Resources']
#
# unique values in column 'EmployeeCount':
#  [1]
#
# unique values in column 'EnvironmentSatisfaction':
#  [2, 3, 4, 1]
#
# unique values in column 'Gender':
#  ['Female', 'Male']
#
# unique values in column 'JobInvolvement':
#  [3, 2, 4, 1]
#
# unique values in column 'JobLevel':
#  [2, 1, 3, 4, 5]
#
# unique values in column 'JobRole':
#  ['Sales Executive', 'Research Scientist', 'Laboratory Technician', 'Manufacturing Director', 'Healthcare Representative', 'Manager', 'Sales Representative', 'Research Director', 'Human Resources']
# ...

# %% [markdown]
# ## Unique Values and Counts II

# %%
column_names = df.columns.tolist()
column_info = []
for col in column_names:
    unique_count = df[col].nunique()
    data_type = df[col].dtype
    column_info.append({'Column Name': col, 'Number of Unique Values': unique_count, 'Data Type': data_type})

columns_info_df = pd.DataFrame(column_info)

# %%
print( column_names )
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
print( column_info )
# Out:
# [{'Column Name': 'Age', 'Number of Unique Values': 43, 'Data Type': dtype('int64')}, {'Column Name': 'Attrition', 'Number of Unique Values': 2, 'Data Type': dtype('O')}, {'Column Name': 'BusinessTravel', 'Number of Unique Values': 3, 'Data Type': dtype('O')}, {'Column Name': 'DailyRate', 'Number of Unique Values': 886, 'Data Type': dtype('int64')}, {'Column Name': 'Department', 'Number of Unique Values': 3, 'Data Type': dtype('O')}, {'Column Name': 'DistanceFromHome', 'Number of Unique Values': 29, 'Data Type': dtype('int64')}, {'Column Name': 'Education', 'Number of Unique Values': 5, 'Data Type': dtype('int64')}, {'Column Name': 'EducationField', 'Number of Unique Values': 6, 'Data Type': dtype('O')}, {'Column Name': 'EmployeeCount', 'Number of Unique Values': 1, 'Data Type': dtype('int64')}, {'Column Name': 'EmployeeNumber', 'Number of Unique Values': 1470, 'Data Type': dtype('int64')}, {'Column Name': 'EnvironmentSatisfaction', 'Number of Unique Values': 4, 'Data Type': dtype('in
# ...

# %%
columns_info_df
# Out:
#                  Column Name  Number of Unique Values Data Type
# 0                        Age                       43     int64
# 1                  Attrition                        2    object
# 2             BusinessTravel                        3    object
# 3                  DailyRate                      886     int64
# 4                 Department                        3    object
# 5           DistanceFromHome                       29     int64
# 6                  Education                        5     int64
# 7             EducationField                        6    object
# 8              EmployeeCount                        1     int64
# 9             EmployeeNumber                     1470     int64
# 10   EnvironmentSatisfaction                        4     int64
# 11                    Gender                        2    object
# 12                HourlyRate                       71     int64
# 13            JobInvolvement                        4     int64
# ...

# %%
print( columns_info_df[(columns_info_df['Number of Unique Values'] <= 20) & (columns_info_df['Data Type']=='object')]['Column Name'].tolist() )
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %%
print( columns_info_df[(columns_info_df['Number of Unique Values'] <= 20) & (columns_info_df['Data Type']=='int64')]['Column Name'].tolist() )
# Out:
# ['Education', 'EmployeeCount', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
low_cardinality_cols_obj = columns_info_df[(columns_info_df['Number of Unique Values'] <= 20) & (columns_info_df['Data Type']=='object')]['Column Name'].tolist()
low_cardinality_cols_int = columns_info_df[(columns_info_df['Number of Unique Values'] <= 20) & (columns_info_df['Data Type']=='int64')]['Column Name'].tolist()

# %%
for col in low_cardinality_cols_obj:
    print(f"unique values in column '{col}':\n {df[col].unique().tolist()}\n")
# Out:
# unique values in column 'Attrition':
#  ['Yes', 'No']
#
# unique values in column 'BusinessTravel':
#  ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
#
# unique values in column 'Department':
#  ['Sales', 'Research & Development', 'Human Resources']
#
# unique values in column 'EducationField':
#  ['Life Sciences', 'Other', 'Medical', 'Marketing', 'Technical Degree', 'Human Resources']
#
# unique values in column 'Gender':
#  ['Female', 'Male']
#
# unique values in column 'JobRole':
#  ['Sales Executive', 'Research Scientist', 'Laboratory Technician', 'Manufacturing Director', 'Healthcare Representative', 'Manager', 'Sales Representative', 'Research Director', 'Human Resources']
#
# unique values in column 'MaritalStatus':
#  ['Single', 'Married', 'Divorced']
#
# unique values in column 'Over18':
#  ['Y']
#
# unique values in column 'OverTime':
#  ['Yes', 'No']

# %%
for col in low_cardinality_cols_int:
    print(f"unique values in column '{col}':\n {df[col].unique().tolist()}\n")
# Out:
# unique values in column 'Education':
#  [2, 1, 4, 3, 5]
#
# unique values in column 'EmployeeCount':
#  [1]
#
# unique values in column 'EnvironmentSatisfaction':
#  [2, 3, 4, 1]
#
# unique values in column 'JobInvolvement':
#  [3, 2, 4, 1]
#
# unique values in column 'JobLevel':
#  [2, 1, 3, 4, 5]
#
# unique values in column 'JobSatisfaction':
#  [4, 2, 3, 1]
#
# unique values in column 'NumCompaniesWorked':
#  [8, 1, 6, 9, 0, 4, 5, 2, 7, 3]
#
# unique values in column 'PercentSalaryHike':
#  [11, 23, 15, 12, 13, 20, 22, 21, 17, 14, 16, 18, 19, 24, 25]
#
# unique values in column 'PerformanceRating':
#  [3, 4]
#
# unique values in column 'RelationshipSatisfaction':
#  [1, 4, 2, 3]
#
# unique values in column 'StandardHours':
#  [80]
#
# unique values in column 'StockOptionLevel':
#  [0, 1, 3, 2]
#
# unique values in column 'TrainingTimesLastYear':
#  [0, 3, 2, 5, 1, 4, 6]
#
# unique values in column 'WorkLifeBalance':
#  [1, 3, 2, 4]
#
# ...

# %% [markdown]
# ## Dupliacted data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Descriptive statistics

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## Attrition Rate

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
attrition = df['Attrition'].value_counts(normalize=True)

# %%
plt.figure(figsize=(6,5))
ax = sns.barplot(x=attrition.index, y=attrition, hue=attrition.index)

for p in ax.patches:
    ax.annotate(f'{p.get_height() * 100:.2f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='bottom')

plt.title('Distribution of Attrition Rate')
plt.xlabel('Attrition')
plt.ylabel('Percentage')
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the analysis, the company's attrition rate is 16.12%. This means that about 16.12% of the employees decided to leave the company during the analyzed period

# %% [markdown]
# ## Average of Tenure

# %%
avg_tenure = df['YearsAtCompany'].mean()
avg_tenure
# Out:
# 7.0081632653061225

# %% [markdown]
# The average tenure of employees before they decided to leave was 7.01 years. With this average tenure, it can be concluded that many employees feel comfortable and have been with the company for a long time.

# %% [markdown]
# ## Age, Gender, Department

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,6))

sns.histplot(data=df, x='Age', kde=True, ax=axes[0])
axes[0].set_title('Distribution Employee by Age')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Count')
axes[0].tick_params(axis='x', labelsize=8, rotation=7)

sns.countplot(data=df, x='Gender', ax=axes[1], hue='Gender')
axes[1].set_title('Distribution Employee by Gender')
axes[1].set_xlabel('Gender')
axes[1].set_ylabel('Count')
axes[1].tick_params(axis='x', labelsize=8, rotation=7)

sns.countplot(data=df, x='Department', ax=axes[2], hue='Department')
axes[2].set_title('Distribution Employee by Department')
axes[2].set_xlabel('Department')
axes[2].set_ylabel('Count')
axes[2].tick_params(axis='x', labelsize=8, rotation=7)

# plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Age: Most of the company's employees are in the 30-35 age group. This
# indicates that the company has many employees who are at a productive and
# experienced age.
#
# 2. Gender: The majority of employees at this company are male. There are
# significantly more male employees than female employees.
#
# 3. Department: Most of the company's employees are concentrated in the
# research and development department. This indicates that the company is
# heavily focused on product or service research and development activities.

# %% [markdown]
# ## Demografic Factors

# %%
df_attrition = df[df['Attrition'] == 'Yes']
df_attrition.head().T
# Out:
#                                        0                       2   \
# Age                                    41                      37
# Attrition                             Yes                     Yes
# BusinessTravel              Travel_Rarely           Travel_Rarely
# DailyRate                            1102                    1373
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       2
# Education                               2                       2
# EducationField              Life Sciences                   Other
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       4
# EnvironmentSatisfaction                 2                       4
# Gender                             Female                    Male
# HourlyRate                             94                      92
# ...

# %%
def calculate_attrition_rate(df, column):
    attrition_counts = df.groupby([column, 'Attrition']).size().unstack(fill_value=0)
    attrition_rate = attrition_counts['Yes'] / attrition_counts.sum(axis=1) * 100
    attrition_rate_df = attrition_rate.reset_index()
    attrition_rate_df.columns = [column, 'AttritionRate']
    return attrition_rate_df

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6))

# KDE plot of Age with Attrition hue
sns.kdeplot(data=df_attrition, x='Age', fill=True, ax=axes[0])
axes[0].set_title('Attrition by Age')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Density')

# Bar plot of Gender count with Attrition hue
attrition_rate_df = calculate_attrition_rate(df, 'Gender')
sns.barplot(data=attrition_rate_df, x='Gender', y='AttritionRate', hue='Gender', ax=axes[1])
axes[1].set_title(f'Attrition Rate by Gender')
axes[1].set_xlabel('Gender')
axes[1].set_ylabel('Attrition Rate (%)')

plt.tight_layout()
plt.show()
